# %% [markdown]
# <a href="https://colab.research.google.com/github/Vam564/Python-Files/blob/main/oct_29_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# ...

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
#1.
sentences_all = []
for j in ["sent"+str(i) for i in range(1,10)]:
    sentences_all = sentences_all + eval(j)
sortedAllSentences = sorted(set(sentences_all))
sortedAllSentences = [word for word in sortedAllSentences if word.isalpha()] 
print(sortedAllSentences)
# Out:
# ['ARTHUR', 'Call', 'Citizens', 'Dashwood', 'Fellow', 'God', 'House', 'I', 'In', 'Ishmael', 'JOIN', 'KING', 'London', 'MALE', 'PMing', 'Park', 'Pierre', 'Representatives', 'SCENE', 'SEXY', 'Saffron', 'Senate', 'Sussex', 'THE', 'The', 'Vinken', 'Whoa', 'a', 'and', 'as', 'attrac', 'been', 'beginning', 'board', 'clop', 'cloud', 'created', 'director', 'discreet', 'earth', 'encounters', 'family', 'for', 'had', 'have', 'heaven', 'in', 'join', 'lady', 'lay', 'lol', 'long', 'me', 'nonexecutive', 'of', 'old', 'older', 'on', 'people', 'problem', 'ragged', 'red', 'seeks', 'settled', 'side', 'single', 'suburb', 'sunset', 'the', 'there', 'to', 'will', 'wind', 'with', 'years']

# %%
#2.
new = text6
ise_list = []
z_list = []
pt_list = []
lower_list = []
for i in text6:
  if "ise" in i:
    ise_list.append(i)
  if "z" in i:
    z_list.append(i)
  if "pt" in i:
    pt_list.append(i)
  if i.islower() == True:
    lower_list.append(i)

print(ise_list)
print(z_list)
print(pt_list)
print(lower_list)
# Out:
# ['wise', 'wise', 'apologise', 'miserable', 'praised', 'surprise', 'surprise', 'surprise', 'noise', 'raised', 'surprise', 'praised']
# ['zone', 'amazes', 'Fetchez', 'Fetchez', 'zoop', 'zoo', 'zhiv', 'frozen', 'zoosh']
# ['empty', 'aptly', 'Thpppppt', 'Thppt', 'Thppt', 'empty', 'Thppppt', 'temptress', 'temptation', 'ptoo', 'Chapter', 'excepting', 'Thpppt']
# ...

# %%
#3.
from nltk.corpus import brown
x=[]
def lexicaldiversitytable(corpus):
    b_c = brown.categories()
    print("Genre", "Tokens" , "Types" , "Lexical Diversity")
    for w in b_c:
      print(w, len(w), len(set(w)), len(w)/len(set(w))*1.0 )
     
lexicaldiversitytable(brown)
# Out:
# Genre Tokens Types Lexical Diversity
# adventure 9 8 1.125
# belles_lettres 14 7 2.0
# editorial 9 8 1.125
# fiction 7 6 1.1666666666666667
# government 10 8 1.25
# hobbies 7 6 1.1666666666666667
# humor 5 5 1.0
# learned 7 6 1.1666666666666667
# lore 4 4 1.0
# mystery 7 6 1.1666666666666667
# news 4 4 1.0
# religion 8 7 1.1428571428571428
# reviews 7 6 1.1666666666666667
# romance 7 7 1.0
# science_fiction 15 9 1.6666666666666667

# %%
#4.
from nltk.corpus import stopwords
most_freq_50_fd=nltk.FreqDist(brown.words(categories='news'))
words=[word for word in most_freq_50_fd]
for word in words:
    if word in stopwords.words('english') or not word.isalpha():
        most_freq_50_fd.pop(word)

print(most_freq_50_fd.most_common(50))
# Out:
# [('The', 806), ('said', 402), ('would', 244), ('He', 191), ('one', 184), ('I', 179), ('last', 161), ('two', 157), ('new', 148), ('first', 143), ('year', 138), ('A', 137), ('home', 127), ('In', 127), ('also', 120), ('It', 115), ('But', 109), ('made', 107), ('years', 102), ('time', 97), ('three', 97), ('New', 93), ('state', 90), ('President', 89), ('week', 86), ('could', 86), ('four', 73), ('man', 72), ('House', 71), ('This', 70), ('back', 69), ('members', 69), ('American', 67), ('may', 66), ('program', 66), ('work', 66), ('get', 66), ('Kennedy', 66), ('John', 65), ('school', 65), ('night', 64), ('State', 63), ('They', 62), ('meeting', 62), ('since', 61), ('per', 61), ('day', 61), ('many', 60), ('There', 58), ('United', 58)]

# %%
#5.

four_letter_word_text5 = [w for w in text5 if len(w) == 4]
# all four letter words in text5
four_words_frequency = FreqDist(four_letter_word_text5)
# all four lettered with frequency in f
letter_pairs = [(j, i) for i, j in four_words_frequency.items()]
#to obtain a list with descending order I have reversed the dictionary
list(reversed(sorted(letter_pairs)))
# Out:
# [(1021, 'JOIN'),
#  (1016, 'PART'),
#  (274, 'that'),
#  (183, 'what'),
#  (181, 'here'),
#  (170, '....'),
#  (164, 'have'),
#  (156, 'like'),
#  (152, 'with'),
#  (142, 'chat'),
#  (137, 'your'),
#  (130, 'good'),
#  (125, 'just'),
#  (107, 'lmao'),
#  (103, 'know'),
#  (98, 'room'),
#  (92, 'from'),
#  (86, 'this'),
#  (81, 'well'),
#  (78, 'hiya'),
#  (78, 'back'),
#  (77, 'they'),
#  (75, 'yeah'),
#  (75, 'dont'),
#  (71, 'want'),
#  (60, 'love'),
#  (58, 'some'),
#  (58, 'guys'),
#  (57, 'been'),
#  (56, 'talk'),
#  (52, 'nice'),
#  (50, 'time'),
#  (48, 'when'),
#  (44, 'make'),
#  (44, 'haha'),
#  (43, 'need'),
#  (43, 'girl'),
#  (42, 'U122'),
#  (41, 'MODE'),
#  (40, 'will'),
#  (40, 'then'),
#  (40, 'much'),
#  (39, 'over'),
#  (38, 'work'),
#  (38, 'were'),
#  (37, 'take'),
#  (36, 'song'),
#  (36, 'U121'),
#  (36, 'U115'),
#  (35, 'seen'),
#  (35, 'even'),
#  (35, 'does'),
#  (35, 'U156'),
#  (35, 'U105'),
#  (34, 'more'),
#  (34, 'damn'),
#  (33, 'only'),
# ...

# %%
#5
#5.2
import operator
string1 = []
for i in text5:
  string1.append(i)
word_frequency={}
for i in string1:
  if i in word_frequency:
        word_frequency[i]+=1        
  else:
        word_frequency[i]=1
sorted_word_frequency = dict( sorted(word_frequency.items(), key=operator.itemgetter(1),reverse=True))
sorted_word_frequency
# Out:
# {'.': 1268,
#  'JOIN': 1021,
#  'PART': 1016,
#  '?': 737,
#  'lol': 704,
#  'to': 658,
#  'i': 648,
#  'the': 646,
#  'you': 635,
#  ',': 596,
#  'I': 576,
#  'a': 568,
#  'hi': 546,
#  'me': 415,
#  '...': 412,
#  'is': 372,
#  '..': 361,
#  'in': 357,
#  'ACTION': 346,
#  '!': 342,
#  'and': 335,
#  'it': 332,
#  'that': 274,
#  'hey': 264,
#  'my': 242,
#  'of': 202,
#  'u': 200,
#  "'s": 195,
#  'for': 188,
#  'on': 186,
#  'what': 183,
#  'here': 181,
#  'are': 178,
#  'not': 170,
#  '....': 170,
#  'do': 168,
#  'all': 165,
#  'have': 164,
#  'up': 160,
#  'like': 156,
#  'no': 155,
#  'with': 152,
#  'chat': 142,
#  'was': 142,
#  "n't": 141,
#  'so': 139,
#  'your': 137,
#  '/': 133,
#  "'m": 133,
#  'good': 130,
#  'im': 128,
#  'how': 128,
#  'too': 125,
#  'just': 125,
#  'any': 123,
#  'there': 120,
#  'U7': 119,
#  'U34': 119,
#  'pm': 108,
#  'wanna': 107,
#  'out': 107,
#  'lmao': 107,
#  'be': 107,
#  'can': 105,
#  'Hi': 104,
#  'know': 103,
#  'get': 102,
# ...
